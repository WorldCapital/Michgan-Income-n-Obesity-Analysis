# %% [markdown]
# # Michigan Income and Obesity Exploratory Data Analysis (EDA)
#
# Michigan Obesity Prevalence data set
#
# https://www.cdc.gov/diabetes/data/countydata/countydataindicators.html
#
# Michigan Income by County
#
# https://datausa.io/profile/geo/michigan/

# %% [markdown]
# ### Data sets were combined into a single dataset, accessible here:
#
#  https://github.com/WorldCapital/Michgan-Income-n-Obesity-Analysis/blob/master/Mich-Income-n-Obesity.csv

# %% [markdown]
# ### Check out the full report here:
#
# https://github.com/WorldCapital/Michgan-Income-n-Obesity-Analysis/blob/master/Mich-Income-n-Obesity-Analysis.pdf

# %%
 import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

mich = pd.read_csv('Mich-Income-n-Obesity.csv')

# %%
# Get some summaries of columns and data types.

print(mich.head(5))
# Out:
#    FIPS Code   County  Obesity Population  Obesity Percent  Income
# 0      26001   Alcona                2792             31.1   37189
# 1      26003    Alger                2340             29.8   37586
# 2      26005  Allegan               24666             30.2   52061
# 3      26007   Alpena                7300             32.1   38016
# 4      26009   Antrim                5889             32.2   45362

# %%
print(len(mich['County'].unique()))
# Out:
# 83

# %% [markdown]
# ## Michigan Income Statistics

# %%
mich['Income'].min()
# Out:
# 29379

# %%
mich['Income'].median()
# Out:
# 41759.0

# %%
mich['Income'].max()
# Out:
# 72359

# %%
plt.title('Box Plot of Michigan Income')
plt.ylabel('Dollars in U.S. $')
mich["Income"].plot.box();

# %%
plt.title('Histogram of Michigan Income')
plt.ylabel('Frequency')
plt.xlabel('Income')
income["Income"].hist();

# %%
mich.mean()
# Out:
# FIPS Code             26083.000000
# Obesity Population    27889.662651
# Obesity Percent          32.081928
# Income                43618.216867
# dtype: float64

# %% [markdown]
# ## State of Michigan County Obesity Statistics

# %%
mich['Obesity Percent'].min()
# Out:
# 24.4

# %%
mich['Obesity Percent'].median()
# Out:
# 32.2

# %%
mich['Obesity Percent'].max()
# Out:
# 38.9

# %%
plt.title('Box Plot of Michigan Obesity %')
plt.ylabel('Percent %')
mich["Obesity Percent"].plot.box();

# %%
plt.title('Histogram of Michigan Obesity %')
plt.ylabel('Frequency')
plt.xlabel('Obesity %')
income["Obesity %"].hist();

# %%
mich['Obesity Population'].min()
# Out:
# 548

# %%
mich['Obesity Population'].median()
# Out:
# 9848.0

# %%
mich['Obesity Population'].max()
# Out:
# 434504

# %%
plt.title('Box Plot of Michigan Obesity Population')
plt.ylabel('Percent %')
mich["Obesity Population"].plot.box();

# %%
income = pd.read_csv('obesity-income2.csv')
plt.title('Histogram of Michigan Obesity Population')
plt.ylabel('Frequency')
plt.xlabel('Obesity Population')
income["Obesity Population"].hist();

# %% [markdown]
# ## Pair plot of Michigan Income by County

# %%
sns.pairplot(mich,kind="reg")
#plt.title('Correlation Pairplot of Michigan Income and Obesity')
plt.show()

# %%
# plot
sns.regplot(x=df_sample["Obesity Population"], 
            y=df_sample["Income"], 
            line_kws={"color":"r","alpha":0.7,"lw":5}
           )

#sns.plt.show()

# %%
# plot
import seaborn as sns


sns.regplot(x=df_sample["Income"], 
            y=df_sample["Obesity Population"], 
            line_kws={"color":"r","alpha":0.7,"lw":5}
           )

#sns.plt.show()

# %%
# plot
sns.regplot(x=df_sample["Obesity %"], 
            y=df_sample["Income"], 
            line_kws={"color":"r","alpha":0.7,"lw":5}
           )

#sns.plt.show()

# %%
# plot
sns.regplot(x=df_sample["Income"], 
            y=df_sample["FIPS Code"], 
            line_kws={"color":"r","alpha":0.7,"lw":5}
           )

#sns.plt.show()

# %%
# plot
sns.regplot(x=df_sample["Obesity Population"], 
            y=df_sample["FIPS Code"], 
            line_kws={"color":"r","alpha":0.7,"lw":5}
           )

# %%
# plot
sns.regplot(x=df_sample["Obesity %"], 
            y=df_sample["FIPS Code"], 
            line_kws={"color":"r","alpha":0.7,"lw":5}
           )

# %%
# plot
sns.regplot(x=df_sample["Obesity %"], 
            y=df_sample["Obesity Population"], 
            line_kws={"color":"r","alpha":0.7,"lw":5}
           )

# %% [markdown]
# ## Correlation Analysis of Michigan Income and Obesity

# %%
mich.corr()
# Out:
#                     FIPS Code  Obesity Population  Obesity Percent    Income
# FIPS Code            1.000000            0.219123         0.040361  0.019849
# Obesity Population   0.219123            1.000000        -0.062344  0.296177
# Obesity Percent      0.040361           -0.062344         1.000000 -0.385183
# Income               0.019849            0.296177        -0.385183  1.000000

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="white")

# Generate a large random dataset
d = mich

# Compute the correlation matrix
corr = d.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
